# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import matplotlib.pyplot as plt
from itertools import product
from lib.io_functions import read_input_file,root2npy,load_npy,save_proccesed_variables

# %%
# Out:
# Loaded run with keys: dict_keys(['NRun', 'NChannel', 2])
# -----------------------------------------------

# %%
my_runs = load_npy([2],[6])
np.save("RAW_CALIB_WVFS_SC.npy",np.asarray(my_runs[2][6]["ADC"]))

my_runs = load_npy([2],[6],"Analysis_","../data/ana/")
np.save("PROCESSED_CALIB_WVFS_SC.npy",np.asarray(my_runs[2][6]["AnaADC"]))

my_runs = load_npy([2],[6],"Average_","../data/ave/")
np.save("AVERAGE_SPE_WVF_SC.npy",np.asarray(my_runs[2][6]["SPEAvWvf"]))
# Out:
# Loaded run with keys: dict_keys(['NRun', 'NChannel', 2])
# -----------------------------------------------
#
# Loaded Analysis_run with keys: dict_keys(['NRun', 'NChannel', 2])
# -----------------------------------------------
#
# Loaded Average_run with keys: dict_keys(['NRun', 'NChannel', 2])
# -----------------------------------------------

# %%
ADC = np.load("RAW_CALIB_WVFS_SC.npy",allow_pickle=True)
# plt.plot(ADC[0])

ADC = np.load("PROCESSED_CALIB_WVFS_SC.npy",allow_pickle=True)
plt.plot(ADC[4])

ADC = np.load("AVERAGE_SPE_WVF_SC.npy",allow_pickle=True)
plt.plot(ADC[0])
# Out:
# El Kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior. Revise el código de las celdas para identificar una posible causa del error. Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información. Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.
