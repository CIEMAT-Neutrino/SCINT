# %%
import sys
sys.path.insert(0, '../')

import numpy as np
from itertools import product
from lib.io_functions import read_input_file,root2npy,load_npy,save_proccesed_variables

# %%
input_file = input("Please select input File: ")
info = read_input_file(input_file)

runs = []; channels = []
runs = np.append(runs,info["CALIB_RUNS"])
runs = np.append(runs,info["LIGHT_RUNS"])
runs = np.append(runs,info["ALPHA_RUNS"])

channels = np.append(channels,info["CHAN_STNRD"])

root2npy(runs.astype(int),channels.astype(int),info=info)
# Out:
# dict_keys(['MONTH', 'SAMPLING', 'OV_LABEL', 'MUONS_RUNS', 'LIGHT_RUNS', 'ALPHA_RUNS', 'CALIB_RUNS', 'CHAN_LABEL', 'CHAN_STNRD', 'CHAN_CALIB', 'CHAN_POLAR'])
# ----------------------
# Dumping file: ../data/raw/run01_ch0.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run01_ch0.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run01_ch1.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run01_ch1.npy
# ----------------------
#
# --- File run01_ch4.root was not foud!!!
#
# ----------------------
# Dumping file: ../data/raw/run01_ch6.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run01_ch6.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run02_ch0.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run02_ch0.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run02_ch1.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run02_ch1.npy
# ----------------------
#
# --- File run02_ch4.root was not foud!!!
#
# ----------------------
# Dumping file: ../data/raw/run02_ch6.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run02_ch6.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run03_ch0.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run03_ch0.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run03_ch1.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run03_ch1.npy
# ----------------------
#
# --- File run03_ch4.root was not foud!!!
#
# ----------------------
# Dumping file: ../data/raw/run03_ch6.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run03_ch6.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run09_ch0.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run09_ch0.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run09_ch1.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run09_ch1.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run09_ch4.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run09_ch4.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run09_ch6.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run09_ch6.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run10_ch0.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run10_ch0.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run10_ch1.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run10_ch1.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run10_ch4.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run10_ch4.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run10_ch6.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run10_ch6.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run11_ch0.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run11_ch0.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run11_ch1.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run11_ch1.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run11_ch4.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run11_ch4.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run11_ch6.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run11_ch6.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run25_ch0.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run25_ch0.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run25_ch1.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run25_ch1.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run25_ch4.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run25_ch4.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run25_ch6.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run25_ch6.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run26_ch0.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run26_ch0.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run26_ch1.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run26_ch1.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run26_ch4.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run26_ch4.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run26_ch6.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run26_ch6.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run27_ch0.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run27_ch0.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run27_ch1.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run27_ch1.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run27_ch4.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run27_ch4.npy
# ----------------------
#
# ----------------------
# Dumping file: ../data/raw/run27_ch6.root
# dict_keys(['ADC', 'Sampling', 'EventNumber', 'TriggerTimeStamp', 'PCTimeStamp', 'NBinsWvf', 'Label', 'PChannel'])
# Saved data in: ../data/raw/run27_ch6.npy
# ----------------------
